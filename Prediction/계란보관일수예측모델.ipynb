# %% [markdown]
# # 계란 보관 일 수 예측 모델
#
# 이 노트북은 인공지능 데이터 구축 사업의 일환인 `계란 데이터 구축 과제` 의 결과물 중 하나인 `계란 보관 데이터` 의 활용 예시를 보여줍니다.
# 본 노트북은 보관 일 수 데이터로부터 학습 데이터를 구축하는 데이터 로더 모듈과 모델 학습 코드를 포함하며 마지막으로 학습된 모델을 사용한 추론 예시를 보여줍니다.

# %% [markdown]
# ## 데이터 셋
#
# 제공되는 계란 보관일 수 예측 데이터 셋은 다음과 같은 구조를 갖습니다.
#
# ```
# /data
# |_1일/
# |   |_세척/
# |   |   |_ 기형/
# |   |   |   |_1234.jpg
# |   |   |   |_1234.xml
# |   |   |- 크랙/
# |   |   |- 혈반/
# |   |   |- 정상/
# |   |   |- 이물질/
# |   |   |- 잠재크랙/
# |   |_비세척/
# |        |_ ...
# |_2일/
# ...
# ```
#
# 해당 데이터로부터 학습 가능한 형태의 데이터 셋을 새로 구축하고 이를 활용하여 모델을 학습합니다.

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

import tensorflow as tf
from tensorflow import keras
import xml.etree.ElementTree as ET
import warnings
warnings.filterwarnings('ignore')

# %%
# 데이터 셋 구축

DATA_PATH = '/ssd_ext/ssd500/yejyang/eggData/신선도'
DATA_CSV = './freshness_data.csv'
if not os.path.isfile(DATA_CSV):

    # load 'image' list & 'label list'
    img_list, label_list, CLASS = [], [], []
    for (path, dir_name, files) in os.walk(DATA_PATH):
        for file in files:

            # if there is 'image' and 'xml'
            if (os.path.splitext(file)[1] == '.jpg') and (os.path.isfile(path + '/' + os.path.splitext(file)[0]+'.xml')):
                img_path = path + '/' + file
                img_list.append(img_path)
                label_list.append(path + '/' + os.path.splitext(file)[0]+'.xml')
                paths = img_path.split(os.path.sep)
                CLASS.append(paths[-3] + '/' + paths[-2])

    # parsing label
    DAY, WASH = [], []
    for label in label_list:
        xml_content = ET.parse(label)
        root = xml_content.getroot()
        # DAY
        DAY.append(int(root.findtext("days")))
        # WASH (0/1)
        WASH.append(int(root.findtext("wash"))-1)


    raw_data = {'IMG': img_list, 'DAY': DAY, 'WASH': WASH, 'CLASS': CLASS}
    data = pd.DataFrame(raw_data)
    data.to_csv(DATA_CSV)

else:
    data = pd.read_csv(DATA_CSV)

# %%
# 데이터 셋 로드 (Train : Validation : Test = 8 : 1 : 1)
random_state = 99
train_df, test_df = train_test_split(data, test_size=0.1, stratify=data['DAY'].values, random_state=random_state)
train_df, val_df = train_test_split(train_df, test_size=0.11, random_state=random_state)

print(f"Dataset is split into Train : Validation : Test = {len(train_df)} : {len(val_df)} : {len(test_df)}")
# Out:
# Dataset is split into Train : Validation : Test = 830832 : 102688 : 103725

# %% [markdown]
# ## 모델 구축
#
# 본 노트북에서는 계란 상태 클래스 없이 이미지와 세척 여부만으로 보관 일 수를 예측하는 모델을 학습한다.
# 이를 위해 데이터를 먼저 모델에 맞는 형태로 전처리를 수행하고 모델을 학습한다.

# %%
def input_loader(sample, img_size=(128, 128)):

    ####################################
    # load image
    ####################################
    img = tf.io.read_file(sample['IMG'])
    if tf.strings.split(sample['IMG'])[-1] == b"jpg":
        img = tf.image.decode_jpeg(img, 3) 
    else: 
        img = tf.image.decode_png(img, 3)
    img = tf.image.resize(img, img_size)

    ####################################
    # wash tag
    ####################################
    wash = sample["WASH"]
    wash = tf.subtract(wash, 1)

    return {"IMG": img, "WASH": wash}


def create_dataset(dataframe, batch_size=256, is_train=True):

    columns = ["IMG", "DAY", "WASH"]
    df = dataframe[columns].copy()
    label = df.pop("DAY")
    dataset = tf.data.Dataset.from_tensor_slices((dict(dataframe), label))
    dataset = dataset.shuffle(buffer_size=len(dataframe))

    if is_train:
        dataset = dataset.shuffle(len(dataframe))

    dataset = dataset.map(lambda x, y: (input_loader(x), y))
    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

    return dataset

# %%
batch_size = 512
dataset_tr = create_dataset(train_df, batch_size=batch_size)
dataset_val = create_dataset(val_df, batch_size=batch_size)
dataset_test = create_dataset(test_df, batch_size=batch_size)
# Out:
# WARNING:tensorflow:From /home/yejyang/anaconda3/envs/kkokkobot_freshness/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %%
# Build multi-modal model

def create_model(is_train=True):

    # image input
    img = keras.Input(shape=(128, 128, 3), name="IMG")
    preprocessed_img = keras.applications.resnet_v2.preprocess_input(img)
    resnet = keras.applications.ResNet50V2(include_top=False, weights="imagenet", pooling="avg")
    resnet.trainable = True
    img_embedding = resnet(preprocessed_img)

    # wash tag
    wash = keras.Input(shape=(1), name="WASH")

    # input construction
    concatenated = keras.layers.concatenate([img_embedding, wash])

    # output head layer
    out = keras.layers.Dense(32, kernel_initializer="normal", activation="relu")(concatenated)
    out = keras.layers.Dense(256, kernel_initializer="normal", activation="relu")(out)
    out = keras.layers.Dense(512, kernel_initializer="normal", activation="relu")(out)
    out = keras.layers.Dense(512, kernel_initializer="normal", activation="relu")(out)
    out = keras.layers.Dense(512, kernel_initializer="normal", activation="relu")(out)
    out = keras.layers.Dense(64, kernel_initializer="normal", activation="relu")(out)
    out = keras.layers.Dense(1, kernel_initializer="normal", activation="relu")(out)

    return keras.Model([img, wash], out)

# %%
# if you train the model with multiple GPUs
mirrored_strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"])
with mirrored_strategy.scope():
    model = create_model()
    model.compile(loss="mse", optimizer="adam", metrics=[keras.metrics.mse, keras.metrics.mean_absolute_error])

# Train model!
epochs = 20
cb_earlyStopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=10, verbose=0, mode="min")
cb_bestSave = tf.keras.callbacks.ModelCheckpoint('./freshness_model_best.hdf5', save_best_only=True, monitor="val_loss", mode="min")
cb_lr_scheduling = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, verbose=1, epsilon=1e-4, mode="min")
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  IMG (InputLayer)               [(None, 128, 128, 3  0           []
#                                 )]
#
#  tf.math.truediv (TFOpLambda)   (None, 128, 128, 3)  0           ['IMG[0][0]']
#
#  tf.math.subtract (TFOpLambda)  (None, 128, 128, 3)  0           ['tf.math.truediv[0][0]']
#
#  resnet50v2 (Functional)        (None, 2048)         23564800    ['tf.math.subtract[0][0]']
#
#  WASH (InputLayer)              [(None, 1)]          0           []
#
#  concatenate (Concatenate)      (None, 2049)         0           ['resnet50v2[0][0]',
#                                                                   'WASH[0][0]']
#
#  dense (Dense)                  (None, 32)           65600       ['concatenate[0][0]']
#
#  dense_1 (Dense)                (None, 256)          8448        ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 512)          131584      ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 512)          262656      ['dense_2[0][0]']
#
#  dense_4 (Dense)                (None, 512)          262656      ['dense_3[0][0]']
#
#  dense_5 (Dense)                (None, 64)           32832       ['dense_4[0][0]']
#
#  dense_6 (Dense)                (None, 1)            65          ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 24,328,641
# Trainable params: 24,283,201
# Non-trainable params: 45,440
# __________________________________________________________________________________________________

# %%
from IPython.display import display, Image
from keras.utils import model_to_dot, plot_model

plot_model(model, to_file='model.png', show_shapes=True)
display(Image('./model.png'))

# %%
train_log = model.fit(dataset_tr, epochs=epochs, validation_data=dataset_val, callbacks=[cb_earlyStopping, 
                                                                                         cb_bestSave, 
                                                                                         cb_lr_scheduling])
# Out:
# Epoch 1/20
# INFO:tensorflow:batch_all_reduce: 186 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 186 all-reduces with algorithm = nccl, num_packs = 1
# 1623/1623 [==============================] - 1009s 579ms/step - loss: 42.6713 - mean_squared_error: 42.6713 - mean_absolute_error: 4.1643 - val_loss: 134.8756 - val_mean_squared_error: 134.8756 - val_mean_absolute_error: 7.9111 - lr: 0.0010
# Epoch 2/20
# 1623/1623 [==============================] - 921s 565ms/step - loss: 20.3234 - mean_squared_error: 20.3234 - mean_absolute_error: 2.7671 - val_loss: 79.9239 - val_mean_squared_error: 79.9239 - val_mean_absolute_error: 5.3359 - lr: 0.0010
# Epoch 3/20
# 1623/1623 [==============================] - 923s 566ms/step - loss: 15.4083 - mean_squared_error: 15.4083 - mean_absolute_error: 2.3576 - val_loss: 101.2813 - val_mean_squared_error: 101.2813 - val_mean_absolute_error: 6.6555 - lr: 0.0010
# Epoch 4/20
# 1623/1623 [==============================] - 924s 567ms/step - loss: 12.7589 - mean_squared_error: 12.7589 - mean_absolute_error: 2.1006 - val_loss: 194.7485 - val_mean_squared_error: 194.7485 - val_mean_absolute_error: 10.6346 - lr: 0.0010
# Epoch 5/20
# 1623/1623 [==============================] - 923s 566ms/step - loss: 11.0107 - mean_squared_error: 11.0107 - mean_absolute_error: 1.9200 - val_loss: 76.0386 - val_mean_squared_error: 76.0386 - val_mean_absolute_error: 5.0330 - lr: 0.0010
# Epoch 6/20
# 1623/1623 [==============================] - 920s 564ms/step - loss: 9.5087 - mean_squared_error: 9.5087 - mean_absolute_error: 1.7558 - val_loss: 184.2858 - val_mean_squared_error: 184.2858 - val_mean_absolute_error: 10.8999 - lr: 0.0010
# Epoch 7/20
# 1623/1623 [==============================] - 919s 564ms/step - loss: 8.3493 - mean_squared_error: 8.3493 - mean_absolute_error: 1.6182 - val_loss: 173.9021 - val_mean_squared_error: 173.9021 - val_mean_absolute_error: 10.1312 - lr: 0.0010
# Epoch 8/20
# 1623/1623 [==============================] - 921s 565ms/step - loss: 7.7745 - mean_squared_error: 7.7745 - mean_absolute_error: 1.5447 - val_loss: 69.9220 - val_mean_squared_error: 69.9220 - val_mean_absolute_error: 4.4582 - lr: 0.0010
# Epoch 9/20
# 1623/1623 [==============================] - 920s 564ms/step - loss: 7.0201 - mean_squared_error: 7.0201 - mean_absolute_error: 1.4410 - val_loss: 177.9847 - val_mean_squared_error: 177.9847 - val_mean_absolute_error: 9.1065 - lr: 0.0010
# Epoch 10/20
# 1623/1623 [==============================] - 920s 564ms/step - loss: 6.2494 - mean_squared_error: 6.2494 - mean_absolute_error: 1.3540 - val_loss: 210.9067 - val_mean_squared_error: 210.9067 - val_mean_absolute_error: 10.0312 - lr: 0.0010
# Epoch 11/20
# 1623/1623 [==============================] - 923s 566ms/step - loss: 5.7153 - mean_squared_error: 5.7153 - mean_absolute_error: 1.2813 - val_loss: 118.6366 - val_mean_squared_error: 118.6366 - val_mean_absolute_error: 5.4744 - lr: 0.0010
# Epoch 12/20
# 1623/1623 [==============================] - 920s 564ms/step - loss: 5.3597 - mean_squared_error: 5.3597 - mean_absolute_error: 1.2310 - val_loss: 216.9738 - val_mean_squared_error: 216.9738 - val_mean_absolute_error: 9.6741 - lr: 0.0010
# Epoch 13/20
# 1623/1623 [==============================] - ETA: 0s - loss: 5.1546 - mean_squared_error: 5.1546 - mean_absolute_error: 1.2060
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 1623/1623 [==============================] - 923s 566ms/step - loss: 5.1546 - mean_squared_error: 5.1546 - mean_absolute_error: 1.2060 - val_loss: 78.4341 - val_mean_squared_error: 78.4341 - val_mean_absolute_error: 5.1884 - lr: 0.0010
# Epoch 14/20
# 1623/1623 [==============================] - 926s 567ms/step - loss: 2.6293 - mean_squared_error: 2.6293 - mean_absolute_error: 0.8840 - val_loss: 5.7992 - val_mean_squared_error: 5.7992 - val_mean_absolute_error: 1.0661 - lr: 1.0000e-04
# Epoch 15/20
# 1623/1623 [==============================] - 923s 566ms/step - loss: 2.0427 - mean_squared_error: 2.0427 - mean_absolute_error: 0.8046 - val_loss: 7.1292 - val_mean_squared_error: 7.1292 - val_mean_absolute_error: 1.2262 - lr: 1.0000e-04
# Epoch 16/20
# 1623/1623 [==============================] - 921s 564ms/step - loss: 1.7130 - mean_squared_error: 1.7130 - mean_absolute_error: 0.7595 - val_loss: 7.0270 - val_mean_squared_error: 7.0270 - val_mean_absolute_error: 1.1096 - lr: 1.0000e-04
# Epoch 17/20
# 1623/1623 [==============================] - 921s 565ms/step - loss: 1.4830 - mean_squared_error: 1.4830 - mean_absolute_error: 0.7227 - val_loss: 7.6463 - val_mean_squared_error: 7.6463 - val_mean_absolute_error: 1.1732 - lr: 1.0000e-04
# Epoch 18/20
# 1623/1623 [==============================] - 919s 564ms/step - loss: 1.3164 - mean_squared_error: 1.3164 - mean_absolute_error: 0.6908 - val_loss: 15.5266 - val_mean_squared_error: 15.5266 - val_mean_absolute_error: 1.6279 - lr: 1.0000e-04
# Epoch 19/20
# 1623/1623 [==============================] - ETA: 0s - loss: 1.2166 - mean_squared_error: 1.2166 - mean_absolute_error: 0.6678
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 1623/1623 [==============================] - 920s 564ms/step - loss: 1.2166 - mean_squared_error: 1.2166 - mean_absolute_error: 0.6678 - val_loss: 6.1711 - val_mean_squared_error: 6.1711 - val_mean_absolute_error: 0.9991 - lr: 1.0000e-04
# Epoch 20/20
# 1623/1623 [==============================] - 920s 564ms/step - loss: 1.0607 - mean_squared_error: 1.0607 - mean_absolute_error: 0.6323 - val_loss: 5.3943 - val_mean_squared_error: 5.3943 - val_mean_absolute_error: 0.9183 - lr: 1.0000e-05

# %%
# Train log plot
import matplotlib.pyplot as plt

plt.plot(train_log.history['mean_absolute_error'])
plt.plot(train_log.history['val_mean_absolute_error'])
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend(['Train', 'Validation'])
plt.grid()
plt.show()

# %%
print(train_log.history['mean_absolute_error'])
print(train_log.history['val_mean_absolute_error'])
# Out:
# [4.164305210113525, 2.7670719623565674, 2.3575692176818848, 2.1006033420562744, 1.9199864864349365, 1.7558022737503052, 1.6182363033294678, 1.5447131395339966, 1.4409513473510742, 1.3539602756500244, 1.281315565109253, 1.231043815612793, 1.206015944480896, 0.8839669227600098, 0.8046099543571472, 0.7594766616821289, 0.722733199596405, 0.6908486485481262, 0.6678323149681091, 0.6323349475860596]
# [7.911132335662842, 5.335886001586914, 6.655516147613525, 10.634586334228516, 5.032959461212158, 10.899927139282227, 10.13116455078125, 4.458198547363281, 9.106467247009277, 10.031157493591309, 5.474393367767334, 9.674055099487305, 5.188356876373291, 1.066055178642273, 1.2262187004089355, 1.1095775365829468, 1.1731690168380737, 1.6279218196868896, 0.9991365075111389, 0.9183441996574402]

# %%
import gc
gc.collect()
tf.keras.backend.clear_session()
# Test trained model (best model)
loaded_model = tf.keras.models.load_model('freshness_model_best.hdf5')
acc = loaded_model.evaluate(dataset_test, batch_size=128)
# Out:
# 203/203 [==============================] - 50s 225ms/step - loss: 5.5644 - mean_squared_error: 5.5644 - mean_absolute_error: 0.9270
